# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Reading the datasets and performing operations on dataframes

# %%
data=pd.read_csv('April_2021.csv')
data
# Out:
#                   District          Mandal       Date  Rain (mm)  \
# 0                 Adilabad  Adilabad Rural  01-Apr-21        0.0
# 1                 Adilabad  Adilabad Rural  02-Apr-21        0.0
# 2                 Adilabad  Adilabad Rural  03-Apr-21        0.0
# 3                 Adilabad  Adilabad Rural  04-Apr-21        0.0
# 4                 Adilabad  Adilabad Rural  05-Apr-21        0.0
# ...                    ...             ...        ...        ...
# 17665  Yadadri Bhuvanagiri   Yadagirigutta  26-Apr-21        0.0
# 17666  Yadadri Bhuvanagiri   Yadagirigutta  27-Apr-21        0.0
# 17667  Yadadri Bhuvanagiri   Yadagirigutta  28-Apr-21        0.0
# 17668  Yadadri Bhuvanagiri   Yadagirigutta  29-Apr-21        0.0
# 17669  Yadadri Bhuvanagiri   Yadagirigutta  30-Apr-21        0.0
#
#        Min Temp (°C)  Max Temp (°C)  Min Humidity (%)  Max Humidity (%)  \
# 0               24.4           41.9              10.6              28.8
# ...

# %%
data['Date'].unique
# Out:
# <bound method Series.unique of 0        01-Apr-21
# 1        02-Apr-21
# 2        03-Apr-21
# 3        04-Apr-21
# 4        05-Apr-21
#            ...
# 17665    26-Apr-21
# 17666    27-Apr-21
# 17667    28-Apr-21
# 17668    29-Apr-21
# 17669    30-Apr-21
# Name: Date, Length: 17670, dtype: object>

# %%
data.dtypes
# Out:
# District                  object
# Mandal                    object
# Date                      object
# Rain (mm)                float64
# Min Temp (°C)            float64
# Max Temp (°C)            float64
# Min Humidity (%)         float64
# Max Humidity (%)         float64
# Min Wind Speed (Kmph)    float64
# Max Wind Speed (Kmph)    float64
# dtype: object

# %%
ar=data['Date'].str.replace('Apr','4')
data['Date']=ar
data
# Out:
#                   District          Mandal     Date  Rain (mm)  Min Temp (°C)  \
# 0                 Adilabad  Adilabad Rural  01-4-21        0.0           24.4
# 1                 Adilabad  Adilabad Rural  02-4-21        0.0           26.2
# 2                 Adilabad  Adilabad Rural  03-4-21        0.0           22.3
# 3                 Adilabad  Adilabad Rural  04-4-21        0.0           21.3
# 4                 Adilabad  Adilabad Rural  05-4-21        0.0           24.1
# ...                    ...             ...      ...        ...            ...
# 17665  Yadadri Bhuvanagiri   Yadagirigutta  26-4-21        0.0           23.7
# 17666  Yadadri Bhuvanagiri   Yadagirigutta  27-4-21        0.0           26.0
# 17667  Yadadri Bhuvanagiri   Yadagirigutta  28-4-21        0.0           24.9
# 17668  Yadadri Bhuvanagiri   Yadagirigutta  29-4-21        0.0           24.9
# 17669  Yadadri Bhuvanagiri   Yadagirigutta  30-4-21        0.0           24.0
#
# ...

# %%
data1=pd.read_excel('Jan_to_Mar_2021.xlsx')
data1
# Out:
#          District     Mandal       Date  Rain (mm)  Min Temp (°C)  \
# 0        Adilabad  Bheempoor 2021-01-01        0.0           10.1
# 1        Adilabad  Bheempoor 2021-01-02        0.0           11.7
# 2        Adilabad  Bheempoor 2021-01-03        0.0           10.4
# 3        Adilabad  Bheempoor 2021-01-04        0.0           13.1
# 4        Adilabad  Bheempoor 2021-01-05        0.0           13.4
# ...           ...        ...        ...        ...            ...
# 53005  Narayanpet      Kosgi 2021-03-27        6.0           22.7
# 53006  Narayanpet      Kosgi 2021-03-28        0.0           22.0
# 53007  Narayanpet      Kosgi 2021-03-29        0.0           22.1
# 53008  Narayanpet      Kosgi 2021-03-30        0.0           22.7
# 53009  Narayanpet      Kosgi 2021-03-31        0.0           22.2
#
#        Max Temp (°C)  Min Humidity (%)  Max Humidity (%)  \
# 0               30.0              37.8              95.7
# ...

# %%
import pandas as pd
data2=pd.read_csv('TS weather data August 2021.csv')
data2
# Out:
#                   District          Mandal       Date  Rain (mm)  \
# 0                 Adilabad  Adilabad Rural  01-Aug-21        0.0
# 1                 Adilabad  Adilabad Rural  02-Aug-21        0.5
# 2                 Adilabad  Adilabad Rural  03-Aug-21        7.0
# 3                 Adilabad  Adilabad Rural  04-Aug-21        7.8
# 4                 Adilabad  Adilabad Rural  05-Aug-21        2.5
# ...                    ...             ...        ...        ...
# 18409  Yadadri Bhuvanagiri   Yadagirigutta  27-Aug-21        3.0
# 18410  Yadadri Bhuvanagiri   Yadagirigutta  28-Aug-21        4.7
# 18411  Yadadri Bhuvanagiri   Yadagirigutta  29-Aug-21        0.4
# 18412  Yadadri Bhuvanagiri   Yadagirigutta  30-Aug-21       81.5
# 18413  Yadadri Bhuvanagiri   Yadagirigutta  31-Aug-21       29.1
#
#        Min Temp (°C)  Max Temp (°C)  Min Humidity (%)  Max Humidity (%)  \
# 0               25.0           31.9              54.8              76.4
# ...

# %%
au=data2['Date'].str.replace('Aug','8')
data2['Date']=au
data2
# Out:
#                   District          Mandal     Date  Rain (mm)  Min Temp (°C)  \
# 0                 Adilabad  Adilabad Rural  01-8-21        0.0           25.0
# 1                 Adilabad  Adilabad Rural  02-8-21        0.5           24.4
# 2                 Adilabad  Adilabad Rural  03-8-21        7.0           23.5
# 3                 Adilabad  Adilabad Rural  04-8-21        7.8           24.0
# 4                 Adilabad  Adilabad Rural  05-8-21        2.5           24.0
# ...                    ...             ...      ...        ...            ...
# 18409  Yadadri Bhuvanagiri   Yadagirigutta  27-8-21        3.0           23.4
# 18410  Yadadri Bhuvanagiri   Yadagirigutta  28-8-21        4.7           24.1
# 18411  Yadadri Bhuvanagiri   Yadagirigutta  29-8-21        0.4           23.2
# 18412  Yadadri Bhuvanagiri   Yadagirigutta  30-8-21       81.5           22.2
# 18413  Yadadri Bhuvanagiri   Yadagirigutta  31-8-21       29.1           22.9
#
# ...

# %%
import pandas as pd
data3=pd.read_csv('TS weather data June 2021.csv')
data3
# Out:
#                   District          Mandal       Date  Rain (mm)  \
# 0                 Adilabad  Adilabad Rural  01-Jun-21        7.5
# 1                 Adilabad  Adilabad Rural  02-Jun-21        5.3
# 2                 Adilabad  Adilabad Rural  03-Jun-21        0.0
# 3                 Adilabad  Adilabad Rural  04-Jun-21        0.0
# 4                 Adilabad  Adilabad Rural  05-Jun-21       20.5
# ...                    ...             ...        ...        ...
# 17815  Yadadri Bhuvanagiri   Yadagirigutta  26-Jun-21        0.0
# 17816  Yadadri Bhuvanagiri   Yadagirigutta  27-Jun-21       27.6
# 17817  Yadadri Bhuvanagiri   Yadagirigutta  28-Jun-21       20.7
# 17818  Yadadri Bhuvanagiri   Yadagirigutta  29-Jun-21        0.0
# 17819  Yadadri Bhuvanagiri   Yadagirigutta  30-Jun-21        0.0
#
#        Min Temp (°C)  Max Temp (°C)  Min Humidity (%)  Max Humidity (%)  \
# 0               26.8           37.2              27.9              68.5
# ...

# %%
ju=data3['Date'].str.replace('Jun','6')
data3['Date']=ju
data3
# Out:
#                   District          Mandal     Date  Rain (mm)  Min Temp (°C)  \
# 0                 Adilabad  Adilabad Rural  01-6-21        7.5           26.8
# 1                 Adilabad  Adilabad Rural  02-6-21        5.3           23.7
# 2                 Adilabad  Adilabad Rural  03-6-21        0.0           25.3
# 3                 Adilabad  Adilabad Rural  04-6-21        0.0           27.5
# 4                 Adilabad  Adilabad Rural  05-6-21       20.5           23.5
# ...                    ...             ...      ...        ...            ...
# 17815  Yadadri Bhuvanagiri   Yadagirigutta  26-6-21        0.0           25.2
# 17816  Yadadri Bhuvanagiri   Yadagirigutta  27-6-21       27.6           22.4
# 17817  Yadadri Bhuvanagiri   Yadagirigutta  28-6-21       20.7           22.9
# 17818  Yadadri Bhuvanagiri   Yadagirigutta  29-6-21        0.0           23.7
# 17819  Yadadri Bhuvanagiri   Yadagirigutta  30-6-21        0.0           25.5
#
# ...

# %%
import pandas as pd
data4=pd.read_csv('TS weather data July 2021.csv')

# %%
j=data4['Date'].str.replace('Jul','7')
data4['Date']=j
data4
# Out:
#                   District          Mandal     Date  Rain (mm)  Min Temp (°C)  \
# 0                 Adilabad  Adilabad Rural  01-7-21       16.8           24.7
# 1                 Adilabad  Adilabad Rural  02-7-21       17.0           25.7
# 2                 Adilabad  Adilabad Rural  03-7-21        0.0           26.3
# 3                 Adilabad  Adilabad Rural  04-7-21        0.0           26.3
# 4                 Adilabad  Adilabad Rural  05-7-21        0.0           28.0
# ...                    ...             ...      ...        ...            ...
# 18409  Yadadri Bhuvanagiri   Yadagirigutta  27-7-21        0.0           24.2
# 18410  Yadadri Bhuvanagiri   Yadagirigutta  28-7-21        0.0           24.3
# 18411  Yadadri Bhuvanagiri   Yadagirigutta  29-7-21        0.0           24.7
# 18412  Yadadri Bhuvanagiri   Yadagirigutta  30-7-21        0.3           24.7
# 18413  Yadadri Bhuvanagiri   Yadagirigutta  31-7-21        0.0           24.8
#
# ...

# %%
import pandas as pd
data5=pd.read_csv('TS weather data May 2021.csv')
data5
# Out:
#                   District          Mandal       Date  Rain (mm)  \
# 0                 Adilabad  Adilabad Rural  01-May-21        0.0
# 1                 Adilabad  Adilabad Rural  01-May-21        0.0
# 2                 Adilabad  Adilabad Rural  02-May-21        0.0
# 3                 Adilabad  Adilabad Rural  02-May-21        0.0
# 4                 Adilabad  Adilabad Rural  03-May-21        0.0
# ...                    ...             ...        ...        ...
# 27726  Yadadri Bhuvanagiri   Yadagirigutta  27-May-21        0.0
# 27727  Yadadri Bhuvanagiri   Yadagirigutta  28-May-21        2.2
# 27728  Yadadri Bhuvanagiri   Yadagirigutta  29-May-21        0.0
# 27729  Yadadri Bhuvanagiri   Yadagirigutta  30-May-21        0.5
# 27730  Yadadri Bhuvanagiri   Yadagirigutta  31-May-21        0.0
#
#        Min Temp (°C)  Max Temp (°C)  Min Humidity (%)  Max Humidity (%)  \
# 0               26.8           39.3               0.0               0.0
# ...

# %%
m=data5['Date'].str.replace('May','5')
data5['Date']=m
data5
# Out:
#                   District          Mandal     Date  Rain (mm)  Min Temp (°C)  \
# 0                 Adilabad  Adilabad Rural  01-5-21        0.0           26.8
# 1                 Adilabad  Adilabad Rural  01-5-21        0.0           26.8
# 2                 Adilabad  Adilabad Rural  02-5-21        0.0           24.0
# 3                 Adilabad  Adilabad Rural  02-5-21        0.0           24.0
# 4                 Adilabad  Adilabad Rural  03-5-21        0.0           24.1
# ...                    ...             ...      ...        ...            ...
# 27726  Yadadri Bhuvanagiri   Yadagirigutta  27-5-21        0.0           28.5
# 27727  Yadadri Bhuvanagiri   Yadagirigutta  28-5-21        2.2           27.4
# 27728  Yadadri Bhuvanagiri   Yadagirigutta  29-5-21        0.0           28.7
# 27729  Yadadri Bhuvanagiri   Yadagirigutta  30-5-21        0.5           25.7
# 27730  Yadadri Bhuvanagiri   Yadagirigutta  31-5-21        0.0           28.2
#
# ...

# %% [markdown]
# # DATA CLEANING

# %%
data.shape
# Out:
# (17670, 10)

# %%
data.dtypes
# Out:
# District                  object
# Mandal                    object
# Date                      object
# Rain (mm)                float64
# Min Temp (°C)            float64
# Max Temp (°C)            float64
# Min Humidity (%)         float64
# Max Humidity (%)         float64
# Min Wind Speed (Kmph)    float64
# Max Wind Speed (Kmph)    float64
# dtype: object

# %%
data[data.notnull()].count()
# Out:
# District                 17670
# Mandal                   17670
# Date                     17670
# Rain (mm)                17670
# Min Temp (°C)            17670
# Max Temp (°C)            17670
# Min Humidity (%)         17670
# Max Humidity (%)         17670
# Min Wind Speed (Kmph)    17670
# Max Wind Speed (Kmph)    17670
# dtype: int64

# %%
data.head()
# Out:
#    District          Mandal     Date  Rain (mm)  Min Temp (°C)  Max Temp (°C)  \
# 0  Adilabad  Adilabad Rural  01-4-21        0.0           24.4           41.9
# 1  Adilabad  Adilabad Rural  02-4-21        0.0           26.2           37.7
# 2  Adilabad  Adilabad Rural  03-4-21        0.0           22.3           38.8
# 3  Adilabad  Adilabad Rural  04-4-21        0.0           21.3           39.9
# 4  Adilabad  Adilabad Rural  05-4-21        0.0           24.1           38.7
#
#    Min Humidity (%)  Max Humidity (%)  Min Wind Speed (Kmph)  \
# 0              10.6              28.8                    0.0
# 1              11.0              26.3                    0.0
# 2               9.5              38.3                    0.0
# 3               7.9              29.2                    0.0
# 4               8.7              45.7                    0.0
#
#    Max Wind Speed (Kmph)
# 0                   10.3
# 1                   11.2
# 2                    9.4
# ...

# %% [markdown]
# ## Dropping min and max wind speeds

# %%
data.drop('Min Wind Speed (Kmph)',axis=1,inplace=True)
data1.drop('Min Wind Speed (Kmph)',axis=1,inplace=True)
data2.drop('Min Wind Speed (Kmph)',axis=1,inplace=True)
data3.drop('Min Wind Speed (Kmph)',axis=1,inplace=True)
data4.drop('Min Wind Speed (Kmph)',axis=1,inplace=True)
data5.drop('Min Wind Speed (Kmph)',axis=1,inplace=True)

# %%
data3['Max Wind Speed (Kmph)'].unique()
# Out:
# array([ 7. ,  4.2,  2. ,  3.7,  8.7,  2.3,  3.5,  3.8,  4.5,  2.5,  3.1,
#         2.8,  4.7,  3.4,  4.3,  2.4,  2.7,  3. ,  1.8,  2.6,  3.9,  3.3,
#         8. ,  7.7,  7.4, 11.2,  8.3,  6.4,  8.5,  9.7,  7.2,  5.8,  8.8,
#         9.5,  7.3,  4.4,  8.1,  4.1,  4.6,  5.7,  6.1,  2.2,  0.1,  6. ,
#         7.5,  4. ,  9.1,  9.4,  1.3,  3.2,  8.4,  6.2,  5.4,  2.1,  1.6,
#         5. ,  3.6,  1.4,  2.9,  6.5,  1.5,  1.9,  6.9,  6.8, 10.4,  8.9,
#         7.9,  6.7, 24.8,  9.9,  1.2,  1.7, 10. ,  9. ,  9.8,  1. , 14.3,
#        13.3, 12.9, 15.1,  5.6, 14.5, 15.7, 11.1, 14.4, 13.4, 13.1, 20. ,
#        12.6, 14.6, 12.1, 15.2, 17.7, 12. , 12.5, 15.3, 17. , 12.3,  7.1,
#        10.7, 10.3, 10.8, 15.8, 13.7, 11.4, 13. , 15. , 12.7, 11.3, 14.7,
#        47.1, 17.1, 22.7, 11.5, 14.2, 16.7, 18.5, 15.5, 18.1, 16.5, 11.7,
#        13.9,  9.2, 10.9, 22.8,  5.5,  9.6,  9.3, 10.6,  4.9,  8.6, 10.2,
#        13.6, 15.4,  5.1, 12.4, 11. , 29. ,  5.9,  5.3,  7.8, 17.8, 22.5,
# ...

# %%
data.drop('Max Wind Speed (Kmph)',axis=1,inplace=True)
data1.drop('Max Wind Speed (Kmph)',axis=1,inplace=True)
data2.drop('Max Wind Speed (Kmph)',axis=1,inplace=True)
data3.drop('Max Wind Speed (Kmph)',axis=1,inplace=True)
data4.drop('Max Wind Speed (Kmph)',axis=1,inplace=True)
data5.drop('Max Wind Speed (Kmph)',axis=1,inplace=True)

# %%
data
# Out:
#                   District          Mandal     Date  Rain (mm)  Min Temp (°C)  \
# 0                 Adilabad  Adilabad Rural  01-4-21        0.0           24.4
# 1                 Adilabad  Adilabad Rural  02-4-21        0.0           26.2
# 2                 Adilabad  Adilabad Rural  03-4-21        0.0           22.3
# 3                 Adilabad  Adilabad Rural  04-4-21        0.0           21.3
# 4                 Adilabad  Adilabad Rural  05-4-21        0.0           24.1
# ...                    ...             ...      ...        ...            ...
# 17665  Yadadri Bhuvanagiri   Yadagirigutta  26-4-21        0.0           23.7
# 17666  Yadadri Bhuvanagiri   Yadagirigutta  27-4-21        0.0           26.0
# 17667  Yadadri Bhuvanagiri   Yadagirigutta  28-4-21        0.0           24.9
# 17668  Yadadri Bhuvanagiri   Yadagirigutta  29-4-21        0.0           24.9
# 17669  Yadadri Bhuvanagiri   Yadagirigutta  30-4-21        0.0           24.0
#
# ...

# %%
data1
# Out:
#          District     Mandal       Date  Rain (mm)  Min Temp (°C)  \
# 0        Adilabad  Bheempoor 2021-01-01        0.0           10.1
# 1        Adilabad  Bheempoor 2021-01-02        0.0           11.7
# 2        Adilabad  Bheempoor 2021-01-03        0.0           10.4
# 3        Adilabad  Bheempoor 2021-01-04        0.0           13.1
# 4        Adilabad  Bheempoor 2021-01-05        0.0           13.4
# ...           ...        ...        ...        ...            ...
# 53005  Narayanpet      Kosgi 2021-03-27        6.0           22.7
# 53006  Narayanpet      Kosgi 2021-03-28        0.0           22.0
# 53007  Narayanpet      Kosgi 2021-03-29        0.0           22.1
# 53008  Narayanpet      Kosgi 2021-03-30        0.0           22.7
# 53009  Narayanpet      Kosgi 2021-03-31        0.0           22.2
#
#        Max Temp (°C)  Min Humidity (%)  Max Humidity (%)
# 0               30.0              37.8              95.7
# 1               29.9              40.6              96.6
# ...

# %%
data2
# Out:
#                   District          Mandal     Date  Rain (mm)  Min Temp (°C)  \
# 0                 Adilabad  Adilabad Rural  01-8-21        0.0           25.0
# 1                 Adilabad  Adilabad Rural  02-8-21        0.5           24.4
# 2                 Adilabad  Adilabad Rural  03-8-21        7.0           23.5
# 3                 Adilabad  Adilabad Rural  04-8-21        7.8           24.0
# 4                 Adilabad  Adilabad Rural  05-8-21        2.5           24.0
# ...                    ...             ...      ...        ...            ...
# 18409  Yadadri Bhuvanagiri   Yadagirigutta  27-8-21        3.0           23.4
# 18410  Yadadri Bhuvanagiri   Yadagirigutta  28-8-21        4.7           24.1
# 18411  Yadadri Bhuvanagiri   Yadagirigutta  29-8-21        0.4           23.2
# 18412  Yadadri Bhuvanagiri   Yadagirigutta  30-8-21       81.5           22.2
# 18413  Yadadri Bhuvanagiri   Yadagirigutta  31-8-21       29.1           22.9
#
# ...

# %%
data3
# Out:
#                   District          Mandal     Date  Rain (mm)  Min Temp (°C)  \
# 0                 Adilabad  Adilabad Rural  01-6-21        7.5           26.8
# 1                 Adilabad  Adilabad Rural  02-6-21        5.3           23.7
# 2                 Adilabad  Adilabad Rural  03-6-21        0.0           25.3
# 3                 Adilabad  Adilabad Rural  04-6-21        0.0           27.5
# 4                 Adilabad  Adilabad Rural  05-6-21       20.5           23.5
# ...                    ...             ...      ...        ...            ...
# 17815  Yadadri Bhuvanagiri   Yadagirigutta  26-6-21        0.0           25.2
# 17816  Yadadri Bhuvanagiri   Yadagirigutta  27-6-21       27.6           22.4
# 17817  Yadadri Bhuvanagiri   Yadagirigutta  28-6-21       20.7           22.9
# 17818  Yadadri Bhuvanagiri   Yadagirigutta  29-6-21        0.0           23.7
# 17819  Yadadri Bhuvanagiri   Yadagirigutta  30-6-21        0.0           25.5
#
# ...

# %%
data4
# Out:
#                   District          Mandal     Date  Rain (mm)  Min Temp (°C)  \
# 0                 Adilabad  Adilabad Rural  01-7-21       16.8           24.7
# 1                 Adilabad  Adilabad Rural  02-7-21       17.0           25.7
# 2                 Adilabad  Adilabad Rural  03-7-21        0.0           26.3
# 3                 Adilabad  Adilabad Rural  04-7-21        0.0           26.3
# 4                 Adilabad  Adilabad Rural  05-7-21        0.0           28.0
# ...                    ...             ...      ...        ...            ...
# 18409  Yadadri Bhuvanagiri   Yadagirigutta  27-7-21        0.0           24.2
# 18410  Yadadri Bhuvanagiri   Yadagirigutta  28-7-21        0.0           24.3
# 18411  Yadadri Bhuvanagiri   Yadagirigutta  29-7-21        0.0           24.7
# 18412  Yadadri Bhuvanagiri   Yadagirigutta  30-7-21        0.3           24.7
# 18413  Yadadri Bhuvanagiri   Yadagirigutta  31-7-21        0.0           24.8
#
# ...

# %%
data5
# Out:
#                   District          Mandal     Date  Rain (mm)  Min Temp (°C)  \
# 0                 Adilabad  Adilabad Rural  01-5-21        0.0           26.8
# 1                 Adilabad  Adilabad Rural  01-5-21        0.0           26.8
# 2                 Adilabad  Adilabad Rural  02-5-21        0.0           24.0
# 3                 Adilabad  Adilabad Rural  02-5-21        0.0           24.0
# 4                 Adilabad  Adilabad Rural  03-5-21        0.0           24.1
# ...                    ...             ...      ...        ...            ...
# 27726  Yadadri Bhuvanagiri   Yadagirigutta  27-5-21        0.0           28.5
# 27727  Yadadri Bhuvanagiri   Yadagirigutta  28-5-21        2.2           27.4
# 27728  Yadadri Bhuvanagiri   Yadagirigutta  29-5-21        0.0           28.7
# 27729  Yadadri Bhuvanagiri   Yadagirigutta  30-5-21        0.5           25.7
# 27730  Yadadri Bhuvanagiri   Yadagirigutta  31-5-21        0.0           28.2
#
# ...

# %%
data5[data5.notnull()].count()
# Out:
# District            27731
# Mandal              27731
# Date                27731
# Rain (mm)           27731
# Min Temp (°C)       27731
# Max Temp (°C)       27731
# Min Humidity (%)    27731
# Max Humidity (%)    27731
# dtype: int64

# %%
data5['Rain (mm)'].nunique()
# Out:
# 358

# %%
data5[data5.isnull()].count()
# Out:
# District            0
# Mandal              0
# Date                0
# Rain (mm)           0
# Min Temp (°C)       0
# Max Temp (°C)       0
# Min Humidity (%)    0
# Max Humidity (%)    0
# dtype: int64

# %%
data[data.isnull()].count()
# Out:
# District            0
# Mandal              0
# Date                0
# Rain (mm)           0
# Min Temp (°C)       0
# Max Temp (°C)       0
# Min Humidity (%)    0
# Max Humidity (%)    0
# dtype: int64

# %%
data1[data1.isnull()].count()
# Out:
# District            0
# Mandal              0
# Date                0
# Rain (mm)           0
# Min Temp (°C)       0
# Max Temp (°C)       0
# Min Humidity (%)    0
# Max Humidity (%)    0
# dtype: int64

# %%
data2[data2.isnull()].count()
# Out:
# District            0
# Mandal              0
# Date                0
# Rain (mm)           0
# Min Temp (°C)       0
# Max Temp (°C)       0
# Min Humidity (%)    0
# Max Humidity (%)    0
# dtype: int64

# %%
data3[data3.isnull()].count()
# Out:
# District            0
# Mandal              0
# Date                0
# Rain (mm)           0
# Min Temp (°C)       0
# Max Temp (°C)       0
# Min Humidity (%)    0
# Max Humidity (%)    0
# dtype: int64

# %%
data4[data4.notnull()].count()
# Out:
# District            18414
# Mandal              18414
# Date                18414
# Rain (mm)           18414
# Min Temp (°C)       18414
# Max Temp (°C)       18414
# Min Humidity (%)    18414
# Max Humidity (%)    18414
# dtype: int64

# %%
data1[data1.notnull()].count()
# Out:
# District            53010
# Mandal              53010
# Date                53010
# Rain (mm)           53010
# Min Temp (°C)       53010
# Max Temp (°C)       53010
# Min Humidity (%)    53010
# Max Humidity (%)    53010
# dtype: int64

# %%
data1.isnull().sum()
# Out:
# District            0
# Mandal              0
# Date                0
# Rain (mm)           0
# Min Temp (°C)       0
# Max Temp (°C)       0
# Min Humidity (%)    0
# Max Humidity (%)    0
# dtype: int64

# %%
data1.isnull().any()
# Out:
# District            False
# Mandal              False
# Date                False
# Rain (mm)           False
# Min Temp (°C)       False
# Max Temp (°C)       False
# Min Humidity (%)    False
# Max Humidity (%)    False
# dtype: bool

# %%
data1
# Out:
#          District     Mandal       Date  Rain (mm)  Min Temp (°C)  \
# 0        Adilabad  Bheempoor 2021-01-01        0.0           10.1
# 1        Adilabad  Bheempoor 2021-01-02        0.0           11.7
# 2        Adilabad  Bheempoor 2021-01-03        0.0           10.4
# 3        Adilabad  Bheempoor 2021-01-04        0.0           13.1
# 4        Adilabad  Bheempoor 2021-01-05        0.0           13.4
# ...           ...        ...        ...        ...            ...
# 53005  Narayanpet      Kosgi 2021-03-27        6.0           22.7
# 53006  Narayanpet      Kosgi 2021-03-28        0.0           22.0
# 53007  Narayanpet      Kosgi 2021-03-29        0.0           22.1
# 53008  Narayanpet      Kosgi 2021-03-30        0.0           22.7
# 53009  Narayanpet      Kosgi 2021-03-31        0.0           22.2
#
#        Max Temp (°C)  Min Humidity (%)  Max Humidity (%)
# 0               30.0              37.8              95.7
# 1               29.9              40.6              96.6
# ...

# %% [markdown]
# ## Changing date column to date time format

# %%
data['Date']=pd.to_datetime(data['Date'],infer_datetime_format=True)

# %%
data.dtypes
# Out:
# District                    object
# Mandal                      object
# Date                datetime64[ns]
# Rain (mm)                  float64
# Min Temp (°C)              float64
# Max Temp (°C)              float64
# Min Humidity (%)           float64
# Max Humidity (%)           float64
# dtype: object

# %%
data1['Date']=pd.to_datetime(data1['Date'],infer_datetime_format=True)
data1.dtypes
# Out:
# District                    object
# Mandal                      object
# Date                datetime64[ns]
# Rain (mm)                  float64
# Min Temp (°C)              float64
# Max Temp (°C)              float64
# Min Humidity (%)           float64
# Max Humidity (%)           float64
# dtype: object

# %%
data2['Date']=pd.to_datetime(data2['Date'],infer_datetime_format=True)
data2.dtypes
# Out:
# District                    object
# Mandal                      object
# Date                datetime64[ns]
# Rain (mm)                  float64
# Min Temp (°C)              float64
# Max Temp (°C)              float64
# Min Humidity (%)           float64
# Max Humidity (%)           float64
# dtype: object

# %%
data3['Date']=pd.to_datetime(data3['Date'],infer_datetime_format=True)
data3.dtypes
# Out:
# District                    object
# Mandal                      object
# Date                datetime64[ns]
# Rain (mm)                  float64
# Min Temp (°C)              float64
# Max Temp (°C)              float64
# Min Humidity (%)           float64
# Max Humidity (%)           float64
# dtype: object

# %%
data4['Date']=pd.to_datetime(data4['Date'],infer_datetime_format=True)
data4.dtypes
# Out:
# District                    object
# Mandal                      object
# Date                datetime64[ns]
# Rain (mm)                  float64
# Min Temp (°C)              float64
# Max Temp (°C)              float64
# Min Humidity (%)           float64
# Max Humidity (%)           float64
# dtype: object

# %%
data5['Date']=pd.to_datetime(data5['Date'],infer_datetime_format=True)
data5.dtypes
# Out:
# District                    object
# Mandal                      object
# Date                datetime64[ns]
# Rain (mm)                  float64
# Min Temp (°C)              float64
# Max Temp (°C)              float64
# Min Humidity (%)           float64
# Max Humidity (%)           float64
# dtype: object

# %%
data['Date'].unique
# Out:
# <bound method Series.unique of 0       2021-01-04
# 1       2021-02-04
# 2       2021-03-04
# 3       2021-04-04
# 4       2021-05-04
#            ...
# 17665   2021-04-26
# 17666   2021-04-27
# 17667   2021-04-28
# 17668   2021-04-29
# 17669   2021-04-30
# Name: Date, Length: 17670, dtype: datetime64[ns]>

# %%
import matplotlib.pyplot as plt
plt.scatter(data['Date'],data['Rain (mm)'],)
